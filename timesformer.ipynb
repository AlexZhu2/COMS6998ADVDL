# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CS_6998')

# %%
from functools import total_ordering
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import AutoModelForVideoClassification
from FitnessData import FitnessData
from tqdm.notebook import tqdm
# Load a pre-trained TimeSformer model from Hugging Face.
# Note: "facebook/timesformer-base-finetuned-k400" is pre-trained on Kinetics-400 (400 classes).
# model = TimeSformerForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400").to(device)
model = AutoModelForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400")
# Modify the classification head to output 22 classes (matching your dataset)
model.config.num_labels = 22
# Replace the classifier with a new linear layer.
model.classifier = nn.Linear(model.config.hidden_size, 22)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

def train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    best_acc = 0.0
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # 使用 tqdm 包裹 train_loader，并添加描述信息
        loop = tqdm(train_loader, desc=f"Epoch [{epoch+1}/{num_epochs}]")
        for videos, labels in train_loader:
            # videos (B, C, T, H, W) = (B, 3, 16, 224, 224)
            # need to become (B, T, C, H, W) = (B, 16, 3, 224, 224)
            videos = videos.permute(0, 2, 1, 3, 4)
            videos, labels = videos.to(device), labels.to(device)
            optimizer.zero_grad()
            # TimeSformer expects inputs in shape (B, C, T, H, W)
            outputs = model(videos).logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * labels.size(0)
            _, predicted = outputs.max(1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            print(f"Epoch [{epoch+1}/{num_epochs}] Loss: {loss.item():.4f} Acc: {100. * correct / total:.2f}%")
            # 更新 tqdm 的显示信息
            loop.set_postfix(loss=loss.item(), acc=100. * correct / total)
        train_acc = 100. * correct / total
        val_acc = validate(model, val_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}] Loss: {running_loss/total:.4f} Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%")
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), "timesformer_best.pth")
            print(f"New Best Model Saved with Accuracy: {best_acc:.2f}%")
    print(f"Finished Training. Best Validation Accuracy: {best_acc:.2f}%")

def validate(model, val_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for videos, labels in val_loader:
            videos = videos.permute(0, 2, 1, 3, 4)
            videos, labels = videos.to(device), labels.to(device)
            outputs = model(videos).logits
            _, predicted = outputs.max(1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    return 100. * correct / total

def evaluate(model, val_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for videos, labels in val_loader:
            videos = videos.permute(0, 2, 1, 3, 4)
            videos, labels = videos.to(device), labels.to(device)
            outputs = model(videos).logits
            _, predicted = outputs.max(1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    val_acc = 100. * correct / total
    print(f"Val Acc: {val_acc:.2f}%")

# %%
# Create dataset and DataLoaders using the provided FitnessData class.
train_dataset = FitnessData(root_dir="/content/drive/MyDrive/CS_6998/workoutfitness-video", train=True, transform=None, frames_per_clip=16)
val_dataset = FitnessData(root_dir="/content/drive/MyDrive/CS_6998/workoutfitness-video", train=False, transform=None, frames_per_clip=16)

batch_size = 2
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Train and validate the model.
train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)

# Load the best saved model for final testing.
model.load_state_dict(torch.load("timesformer_best.pth"))
print("Loaded Best Model for Final Testing")
final_acc = validate(model, val_loader)
print(f"Final Model Accuracy: {final_acc:.2f}%")
# Out:
# Epoch [1/10]:   0%|          | 0/218 [00:00<?, ?it/s]
# Epoch [1/10] Loss: 3.3916 Acc: 0.00%
# Epoch [1/10] Loss: 3.1693 Acc: 0.00%
# Epoch [1/10] Loss: 3.6560 Acc: 0.00%
# Epoch [1/10] Loss: 2.7209 Acc: 0.00%
# Epoch [1/10] Loss: 3.8801 Acc: 0.00%
# Epoch [1/10] Loss: 1.4196 Acc: 16.67%
# Epoch [1/10] Loss: 3.3361 Acc: 21.43%
# Epoch [1/10] Loss: 3.3071 Acc: 18.75%
# Epoch [1/10] Loss: 3.1172 Acc: 16.67%
# Epoch [1/10] Loss: 1.9021 Acc: 20.00%
# Epoch [1/10] Loss: 3.1826 Acc: 18.18%
# Epoch [1/10] Loss: 1.5950 Acc: 20.83%
# Epoch [1/10] Loss: 4.6918 Acc: 19.23%
# Epoch [1/10] Loss: 3.3071 Acc: 17.86%
# Epoch [1/10] Loss: 2.0148 Acc: 16.67%
# Epoch [1/10] Loss: 3.8444 Acc: 15.62%
# Epoch [1/10] Loss: 3.1831 Acc: 14.71%
# Epoch [1/10] Loss: 1.1819 Acc: 16.67%
# Epoch [1/10] Loss: 1.9648 Acc: 18.42%
# Epoch [1/10] Loss: 1.3095 Acc: 22.50%
# Epoch [1/10] Loss: 3.0473 Acc: 21.43%
# Epoch [1/10] Loss: 1.4718 Acc: 22.73%
# Epoch [1/10] Loss: 2.2984 Acc: 21.74%
# Epoch [1/10] Loss: 3.4071 Acc: 20.83%
# Epoch [1/10] Loss: 2.4207 Acc: 20.00%
# Epoch [1/10] Loss: 1.2731 Acc: 23.08%
# Epoch [1/10] Loss: 1.7111 Acc: 25.93%
# Epoch [1/10] Loss: 2.3760 Acc: 25.00%
# Epoch [1/10] Loss: 5.6189 Acc: 24.14%
# Epoch [1/10] Loss: 2.0895 Acc: 25.00%
# Epoch [1/10] Loss: 2.9586 Acc: 25.81%
# Epoch [1/10] Loss: 0.4991 Acc: 28.12%
# Epoch [1/10] Loss: 0.3072 Acc: 30.30%
# Epoch [1/10] Loss: 1.7224 Acc: 30.88%
# Epoch [1/10] Loss: 3.5786 Acc: 30.00%
# Epoch [1/10] Loss: 2.8898 Acc: 30.56%
# Epoch [1/10] Loss: 1.7753 Acc: 31.08%
# Epoch [1/10] Loss: 0.8691 Acc: 31.58%
# Epoch [1/10] Loss: 0.0710 Acc: 33.33%
# Epoch [1/10] Loss: 3.0899 Acc: 33.75%
# Epoch [1/10] Loss: 2.1872 Acc: 34.15%
# Epoch [1/10] Loss: 1.1463 Acc: 34.52%
# Epoch [1/10] Loss: 2.5268 Acc: 34.88%
# Epoch [1/10] Loss: 1.6463 Acc: 35.23%
# Epoch [1/10] Loss: 1.5468 Acc: 35.56%
# Epoch [1/10] Loss: 1.6399 Acc: 35.87%
# Epoch [1/10] Loss: 2.1330 Acc: 36.17%
# Epoch [1/10] Loss: 1.5402 Acc: 36.46%
# Epoch [1/10] Loss: 3.0338 Acc: 35.71%
# Epoch [1/10] Loss: 2.0930 Acc: 36.00%
# Epoch [1/10] Loss: 1.7263 Acc: 35.29%
# Epoch [1/10] Loss: 2.4655 Acc: 35.58%
# Epoch [1/10] Loss: 1.2629 Acc: 35.85%
# Epoch [1/10] Loss: 1.4282 Acc: 36.11%
# Epoch [1/10] Loss: 0.5863 Acc: 37.27%
# Epoch [1/10] Loss: 1.2993 Acc: 38.39%
# Epoch [1/10] Loss: 0.8696 Acc: 38.60%
# Epoch [1/10] Loss: 0.8773 Acc: 39.66%
# Epoch [1/10] Loss: 0.5968 Acc: 40.68%
# Epoch [1/10] Loss: 3.5320 Acc: 40.83%
# Epoch [1/10] Loss: 1.5607 Acc: 40.98%
# Epoch [1/10] Loss: 0.7933 Acc: 41.94%
# Epoch [1/10] Loss: 1.5078 Acc: 42.06%
# Epoch [1/10] Loss: 0.8050 Acc: 42.97%
# Epoch [1/10] Loss: 0.3218 Acc: 43.85%
# Epoch [1/10] Loss: 1.5887 Acc: 43.94%
# Epoch [1/10] Loss: 0.4885 Acc: 44.78%
# Epoch [1/10] Loss: 3.8320 Acc: 44.12%
# Epoch [1/10] Loss: 0.1795 Acc: 44.93%
# Epoch [1/10] Loss: 0.1730 Acc: 45.71%
# Epoch [1/10] Loss: 0.4360 Acc: 46.48%
# Epoch [1/10] Loss: 1.3931 Acc: 46.53%
# Epoch [1/10] Loss: 2.9002 Acc: 45.89%
# Epoch [1/10] Loss: 0.7126 Acc: 46.62%
# Epoch [1/10] Loss: 1.1042 Acc: 46.67%
# Epoch [1/10] Loss: 0.3129 Acc: 47.37%
# Epoch [1/10] Loss: 0.8530 Acc: 48.05%
# Epoch [1/10] Loss: 1.3823 Acc: 48.08%
# Epoch [1/10] Loss: 1.9871 Acc: 48.10%
# Epoch [1/10] Loss: 0.5769 Acc: 48.75%
# Epoch [1/10] Loss: 1.8561 Acc: 48.77%
# Epoch [1/10] Loss: 1.3639 Acc: 48.78%
# Epoch [1/10] Loss: 1.5802 Acc: 48.19%
# Epoch [1/10] Loss: 0.5741 Acc: 48.81%
# Epoch [1/10] Loss: 0.2318 Acc: 49.41%
# Epoch [1/10] Loss: 0.9657 Acc: 50.00%
# Epoch [1/10] Loss: 0.3650 Acc: 50.57%
# Epoch [1/10] Loss: 1.0567 Acc: 50.57%
# Epoch [1/10] Loss: 2.1067 Acc: 50.56%
# Epoch [1/10] Loss: 0.6492 Acc: 51.11%
# Epoch [1/10] Loss: 2.4308 Acc: 50.55%
# Epoch [1/10] Loss: 0.3150 Acc: 51.09%
# Epoch [1/10] Loss: 0.6675 Acc: 51.61%
# Epoch [1/10] Loss: 0.2154 Acc: 52.13%
# Epoch [1/10] Loss: 4.0020 Acc: 51.58%
# Epoch [1/10] Loss: 0.9827 Acc: 51.56%
# Epoch [1/10] Loss: 0.7265 Acc: 52.06%
# Epoch [1/10] Loss: 0.1459 Acc: 52.55%
# Epoch [1/10] Loss: 0.9485 Acc: 52.53%
# Epoch [1/10] Loss: 1.2527 Acc: 52.50%
# Epoch [1/10] Loss: 3.3580 Acc: 52.48%
# Epoch [1/10] Loss: 0.4555 Acc: 52.94%
# Epoch [1/10] Loss: 0.1696 Acc: 53.40%
# Epoch [1/10] Loss: 0.3019 Acc: 53.85%
# Epoch [1/10] Loss: 0.2286 Acc: 54.29%
# Epoch [1/10] Loss: 4.1494 Acc: 53.77%
# Epoch [1/10] Loss: 1.4107 Acc: 53.74%
# Epoch [1/10] Loss: 1.8147 Acc: 53.70%
# Epoch [1/10] Loss: 1.0792 Acc: 54.13%
# Epoch [1/10] Loss: 0.5355 Acc: 54.55%
# Epoch [1/10] Loss: 0.0620 Acc: 54.95%
# Epoch [1/10] Loss: 0.6478 Acc: 55.36%
# Epoch [1/10] Loss: 0.9954 Acc: 55.31%
# Epoch [1/10] Loss: 0.2863 Acc: 55.70%
# Epoch [1/10] Loss: 1.7699 Acc: 55.65%
# Epoch [1/10] Loss: 1.5376 Acc: 55.60%
# Epoch [1/10] Loss: 1.9524 Acc: 55.56%
# Epoch [1/10] Loss: 0.5027 Acc: 55.93%
# Epoch [1/10] Loss: 0.5009 Acc: 56.30%
# Epoch [1/10] Loss: 1.5574 Acc: 56.25%
# Epoch [1/10] Loss: 1.2271 Acc: 56.20%
# Epoch [1/10] Loss: 0.0960 Acc: 56.56%
# Epoch [1/10] Loss: 1.2365 Acc: 56.50%
# Epoch [1/10] Loss: 1.8695 Acc: 56.45%
# Epoch [1/10] Loss: 2.2167 Acc: 56.00%
# Epoch [1/10] Loss: 1.3301 Acc: 55.95%
# Epoch [1/10] Loss: 0.3114 Acc: 56.30%
# Epoch [1/10] Loss: 1.8774 Acc: 56.25%
# Epoch [1/10] Loss: 0.3324 Acc: 56.59%
# Epoch [1/10] Loss: 0.1400 Acc: 56.92%
# Epoch [1/10] Loss: 1.0924 Acc: 56.87%
# Epoch [1/10] Loss: 1.6586 Acc: 56.82%
# Epoch [1/10] Loss: 2.2111 Acc: 56.39%
# Epoch [1/10] Loss: 2.2776 Acc: 56.34%
# Epoch [1/10] Loss: 1.6168 Acc: 55.93%
# Epoch [1/10] Loss: 0.5857 Acc: 56.25%
# Epoch [1/10] Loss: 1.6378 Acc: 56.20%
# Epoch [1/10] Loss: 0.5618 Acc: 56.52%
# Epoch [1/10] Loss: 0.9517 Acc: 56.47%
# Epoch [1/10] Loss: 0.3579 Acc: 56.79%
# Epoch [1/10] Loss: 1.9694 Acc: 56.74%
# Epoch [1/10] Loss: 1.7624 Acc: 56.34%
# Epoch [1/10] Loss: 0.0697 Acc: 56.64%
# Epoch [1/10] Loss: 1.1851 Acc: 56.60%
# Epoch [1/10] Loss: 1.7368 Acc: 56.55%
# Epoch [1/10] Loss: 0.4078 Acc: 56.85%
# Epoch [1/10] Loss: 1.0417 Acc: 56.80%
# Epoch [1/10] Loss: 0.0803 Acc: 57.09%
# Epoch [1/10] Loss: 0.2918 Acc: 57.38%
# Epoch [1/10] Loss: 1.4579 Acc: 57.33%
# Epoch [1/10] Loss: 0.4158 Acc: 57.62%
# Epoch [1/10] Loss: 0.1049 Acc: 57.89%
# Epoch [1/10] Loss: 1.3413 Acc: 57.84%
# Epoch [1/10] Loss: 0.5189 Acc: 58.12%
# Epoch [1/10] Loss: 1.8437 Acc: 58.06%
# Epoch [1/10] Loss: 0.1507 Acc: 58.33%
# Epoch [1/10] Loss: 0.3540 Acc: 58.60%
# Epoch [1/10] Loss: 0.5307 Acc: 58.86%
# Epoch [1/10] Loss: 2.0022 Acc: 58.81%
# Epoch [1/10] Loss: 2.8644 Acc: 58.44%
# Epoch [1/10] Loss: 0.5610 Acc: 58.70%
# Epoch [1/10] Loss: 0.2620 Acc: 58.95%
# Epoch [1/10] Loss: 0.4762 Acc: 59.20%
# Epoch [1/10] Loss: 0.4560 Acc: 59.45%
# Epoch [1/10] Loss: 0.0324 Acc: 59.70%
# Epoch [1/10] Loss: 0.1400 Acc: 59.94%
# Epoch [1/10] Loss: 2.1652 Acc: 59.88%
# Epoch [1/10] Loss: 2.6011 Acc: 59.82%
# Epoch [1/10] Loss: 0.4777 Acc: 60.06%
# Epoch [1/10] Loss: 0.3379 Acc: 60.29%
# Epoch [1/10] Loss: 1.1626 Acc: 60.23%
# Epoch [1/10] Loss: 0.4066 Acc: 60.47%
# Epoch [1/10] Loss: 2.4428 Acc: 60.40%
# Epoch [1/10] Loss: 0.0896 Acc: 60.63%
# Epoch [1/10] Loss: 2.1876 Acc: 60.57%
# Epoch [1/10] Loss: 1.1617 Acc: 60.51%
# Epoch [1/10] Loss: 0.4332 Acc: 60.73%
# Epoch [1/10] Loss: 0.2298 Acc: 60.96%
# Epoch [1/10] Loss: 0.3443 Acc: 61.17%
# Epoch [1/10] Loss: 0.1171 Acc: 61.39%
# Epoch [1/10] Loss: 0.1268 Acc: 61.60%
# Epoch [1/10] Loss: 2.1421 Acc: 61.26%
# Epoch [1/10] Loss: 0.0888 Acc: 61.48%
# Epoch [1/10] Loss: 0.7927 Acc: 61.68%
# Epoch [1/10] Loss: 0.8006 Acc: 61.62%
# Epoch [1/10] Loss: 0.1281 Acc: 61.83%
# Epoch [1/10] Loss: 0.8966 Acc: 61.76%
# Epoch [1/10] Loss: 0.0489 Acc: 61.97%
# Epoch [1/10] Loss: 0.1838 Acc: 62.17%
# Epoch [1/10] Loss: 1.8327 Acc: 62.11%
# Epoch [1/10] Loss: 0.1073 Acc: 62.30%
# Epoch [1/10] Loss: 0.0562 Acc: 62.50%
# Epoch [1/10] Loss: 0.2283 Acc: 62.69%
# Epoch [1/10] Loss: 0.3518 Acc: 62.89%
# Epoch [1/10] Loss: 0.1043 Acc: 63.08%
# Epoch [1/10] Loss: 0.0603 Acc: 63.27%
# Epoch [1/10] Loss: 0.9574 Acc: 63.20%
# Epoch [1/10] Loss: 0.3347 Acc: 63.38%
# Epoch [1/10] Loss: 0.0819 Acc: 63.57%
# Epoch [1/10] Loss: 1.6195 Acc: 63.50%
# Epoch [1/10] Loss: 0.5093 Acc: 63.68%
# Epoch [1/10] Loss: 0.4108 Acc: 63.86%
# Epoch [1/10] Loss: 0.0668 Acc: 64.04%
# Epoch [1/10] Loss: 0.7111 Acc: 64.22%
# Epoch [1/10] Loss: 0.2615 Acc: 64.39%
# Epoch [1/10] Loss: 0.0998 Acc: 64.56%
# Epoch [1/10] Loss: 0.0740 Acc: 64.73%
# Epoch [1/10] Loss: 0.7308 Acc: 64.66%
# Epoch [1/10] Loss: 0.2896 Acc: 64.83%
# Epoch [1/10] Loss: 0.7413 Acc: 64.76%
# Epoch [1/10] Loss: 1.3413 Acc: 64.69%
# Epoch [1/10] Loss: 0.4057 Acc: 64.86%
# Epoch [1/10] Loss: 0.4929 Acc: 65.02%
# Epoch [1/10] Loss: 1.2260 Acc: 64.95%
# Epoch [1/10] Loss: 0.2004 Acc: 65.12%
# Epoch [1/10] Loss: 0.3821 Acc: 65.28%
# Epoch [1/10] Loss: 0.0381 Acc: 65.44%
# Epoch [1/10] Loss: 0.7533 Acc: 65.60%
# Epoch [1/10] Loss: 1.2932 Train Acc: 65.60% | Val Acc: 82.05%
# New Best Model Saved with Accuracy: 82.05%
# Epoch [2/10]:   0%|          | 0/218 [00:00<?, ?it/s]
# Epoch [2/10] Loss: 0.3148 Acc: 100.00%
# Epoch [2/10] Loss: 0.0791 Acc: 100.00%
# Epoch [2/10] Loss: 0.3364 Acc: 100.00%
# Epoch [2/10] Loss: 0.0158 Acc: 100.00%
# Epoch [2/10] Loss: 0.2613 Acc: 100.00%
# Epoch [2/10] Loss: 0.0214 Acc: 100.00%
# Epoch [2/10] Loss: 1.4611 Acc: 92.86%
# Epoch [2/10] Loss: 0.5906 Acc: 87.50%
# Epoch [2/10] Loss: 0.9940 Acc: 83.33%
# Epoch [2/10] Loss: 0.0910 Acc: 85.00%
# Epoch [2/10] Loss: 0.0527 Acc: 86.36%
# Epoch [2/10] Loss: 0.3774 Acc: 87.50%
# Epoch [2/10] Loss: 0.0288 Acc: 88.46%
# Epoch [2/10] Loss: 0.4397 Acc: 89.29%
# Epoch [2/10] Loss: 0.1607 Acc: 90.00%
# Epoch [2/10] Loss: 0.0775 Acc: 90.62%
# Epoch [2/10] Loss: 0.3057 Acc: 91.18%
# Epoch [2/10] Loss: 0.1655 Acc: 91.67%
# Epoch [2/10] Loss: 0.0797 Acc: 92.11%
# Epoch [2/10] Loss: 0.2798 Acc: 92.50%
# Epoch [2/10] Loss: 0.2019 Acc: 92.86%
# Epoch [2/10] Loss: 0.7116 Acc: 90.91%
# Epoch [2/10] Loss: 0.0733 Acc: 91.30%
# Epoch [2/10] Loss: 0.0147 Acc: 91.67%
# Epoch [2/10] Loss: 0.2878 Acc: 92.00%
# Epoch [2/10] Loss: 0.0569 Acc: 92.31%
# Epoch [2/10] Loss: 0.1521 Acc: 92.59%
# Epoch [2/10] Loss: 0.9728 Acc: 91.07%
# Epoch [2/10] Loss: 0.1602 Acc: 91.38%
# Epoch [2/10] Loss: 0.1476 Acc: 91.67%
# Epoch [2/10] Loss: 0.0499 Acc: 91.94%
# Epoch [2/10] Loss: 0.0163 Acc: 92.19%
# Epoch [2/10] Loss: 0.0282 Acc: 92.42%
# Epoch [2/10] Loss: 0.2708 Acc: 92.65%
# Epoch [2/10] Loss: 0.0769 Acc: 92.86%
# Epoch [2/10] Loss: 0.0175 Acc: 93.06%
# Epoch [2/10] Loss: 0.1049 Acc: 93.24%
# Epoch [2/10] Loss: 0.4969 Acc: 92.11%
# Epoch [2/10] Loss: 0.0703 Acc: 92.31%
# Epoch [2/10] Loss: 0.0341 Acc: 92.50%
# Epoch [2/10] Loss: 0.0770 Acc: 92.68%
# Epoch [2/10] Loss: 0.0501 Acc: 92.86%
# Epoch [2/10] Loss: 0.0345 Acc: 93.02%
# Epoch [2/10] Loss: 0.0281 Acc: 93.18%
# Epoch [2/10] Loss: 0.1125 Acc: 93.33%
# Epoch [2/10] Loss: 0.0656 Acc: 93.48%
# Epoch [2/10] Loss: 0.1009 Acc: 93.62%
# Epoch [2/10] Loss: 0.8472 Acc: 92.71%
# Epoch [2/10] Loss: 0.0430 Acc: 92.86%
# Epoch [2/10] Loss: 0.0288 Acc: 93.00%
# Epoch [2/10] Loss: 0.0872 Acc: 93.14%
# Epoch [2/10] Loss: 0.0255 Acc: 93.27%
# Epoch [2/10] Loss: 0.0123 Acc: 93.40%
# Epoch [2/10] Loss: 0.0349 Acc: 93.52%
# Epoch [2/10] Loss: 0.0340 Acc: 93.64%
# Epoch [2/10] Loss: 0.0116 Acc: 93.75%
# Epoch [2/10] Loss: 0.1677 Acc: 93.86%
# Epoch [2/10] Loss: 0.1268 Acc: 93.97%
# Epoch [2/10] Loss: 0.0430 Acc: 94.07%
# Epoch [2/10] Loss: 0.0088 Acc: 94.17%
# Epoch [2/10] Loss: 1.3748 Acc: 93.44%
# Epoch [2/10] Loss: 0.1021 Acc: 93.55%
# Epoch [2/10] Loss: 0.2519 Acc: 93.65%
# Epoch [2/10] Loss: 0.0123 Acc: 93.75%
# Epoch [2/10] Loss: 0.0277 Acc: 93.85%
# Epoch [2/10] Loss: 0.0178 Acc: 93.94%
# Epoch [2/10] Loss: 0.5649 Acc: 93.28%
# Epoch [2/10] Loss: 0.0481 Acc: 93.38%
# Epoch [2/10] Loss: 0.1488 Acc: 93.48%
# Epoch [2/10] Loss: 0.0359 Acc: 93.57%
# Epoch [2/10] Loss: 0.0954 Acc: 93.66%
# Epoch [2/10] Loss: 0.0524 Acc: 93.75%
# Epoch [2/10] Loss: 0.7133 Acc: 93.84%
# Epoch [2/10] Loss: 0.0228 Acc: 93.92%
# Epoch [2/10] Loss: 0.0238 Acc: 94.00%
# Epoch [2/10] Loss: 0.0156 Acc: 94.08%
# Epoch [2/10] Loss: 0.1340 Acc: 94.16%
# Epoch [2/10] Loss: 0.0147 Acc: 94.23%
# Epoch [2/10] Loss: 0.0345 Acc: 94.30%
# Epoch [2/10] Loss: 0.1435 Acc: 94.38%
# Epoch [2/10] Loss: 0.0713 Acc: 94.44%
# Epoch [2/10] Loss: 0.0140 Acc: 94.51%
# Epoch [2/10] Loss: 0.0309 Acc: 94.58%
# Epoch [2/10] Loss: 0.0128 Acc: 94.64%
# Epoch [2/10] Loss: 0.1979 Acc: 94.71%
# Epoch [2/10] Loss: 0.0071 Acc: 94.77%
# Epoch [2/10] Loss: 0.0350 Acc: 94.83%
# Epoch [2/10] Loss: 0.0286 Acc: 94.89%
# Epoch [2/10] Loss: 0.0675 Acc: 94.94%
# Epoch [2/10] Loss: 0.0094 Acc: 95.00%
# Epoch [2/10] Loss: 0.0158 Acc: 95.05%
# Epoch [2/10] Loss: 0.0036 Acc: 95.11%
# Epoch [2/10] Loss: 0.6523 Acc: 94.62%
# Epoch [2/10] Loss: 0.0075 Acc: 94.68%
# Epoch [2/10] Loss: 0.0219 Acc: 94.74%
# Epoch [2/10] Loss: 0.0445 Acc: 94.79%
# Epoch [2/10] Loss: 0.0051 Acc: 94.85%
# Epoch [2/10] Loss: 0.0088 Acc: 94.90%
# Epoch [2/10] Loss: 0.0094 Acc: 94.95%
# Epoch [2/10] Loss: 0.1407 Acc: 95.00%
# Epoch [2/10] Loss: 0.0457 Acc: 95.05%
# Epoch [2/10] Loss: 0.0444 Acc: 95.10%
# Epoch [2/10] Loss: 0.0427 Acc: 95.15%
# Epoch [2/10] Loss: 0.0177 Acc: 95.19%
# Epoch [2/10] Loss: 0.0203 Acc: 95.24%
# Epoch [2/10] Loss: 0.0108 Acc: 95.28%
# Epoch [2/10] Loss: 0.0317 Acc: 95.33%
# Epoch [2/10] Loss: 0.0809 Acc: 95.37%
# Epoch [2/10] Loss: 0.0141 Acc: 95.41%
# Epoch [2/10] Loss: 0.0111 Acc: 95.45%
# Epoch [2/10] Loss: 0.0061 Acc: 95.50%
# Epoch [2/10] Loss: 0.1360 Acc: 95.54%
# Epoch [2/10] Loss: 0.4411 Acc: 95.13%
# Epoch [2/10] Loss: 0.0117 Acc: 95.18%
# Epoch [2/10] Loss: 0.3038 Acc: 95.22%
# Epoch [2/10] Loss: 0.0404 Acc: 95.26%
# Epoch [2/10] Loss: 0.0106 Acc: 95.30%
# Epoch [2/10] Loss: 0.0088 Acc: 95.34%
# Epoch [2/10] Loss: 0.1735 Acc: 95.38%
# Epoch [2/10] Loss: 0.0243 Acc: 95.42%
# Epoch [2/10] Loss: 0.0349 Acc: 95.45%
# Epoch [2/10] Loss: 0.0447 Acc: 95.49%
# Epoch [2/10] Loss: 0.0123 Acc: 95.53%
# Epoch [2/10] Loss: 0.0061 Acc: 95.56%
# Epoch [2/10] Loss: 0.1209 Acc: 95.60%
# Epoch [2/10] Loss: 0.2168 Acc: 95.63%
# Epoch [2/10] Loss: 0.0303 Acc: 95.67%
# Epoch [2/10] Loss: 0.2029 Acc: 95.70%
# Epoch [2/10] Loss: 0.0107 Acc: 95.74%
# Epoch [2/10] Loss: 0.0194 Acc: 95.77%
# Epoch [2/10] Loss: 0.0113 Acc: 95.80%
# Epoch [2/10] Loss: 0.0201 Acc: 95.83%
# Epoch [2/10] Loss: 0.0324 Acc: 95.86%
# Epoch [2/10] Loss: 0.0196 Acc: 95.90%
# Epoch [2/10] Loss: 0.0181 Acc: 95.93%
# Epoch [2/10] Loss: 0.0912 Acc: 95.96%
# Epoch [2/10] Loss: 0.0480 Acc: 95.99%
# Epoch [2/10] Loss: 0.0489 Acc: 96.01%
# Epoch [2/10] Loss: 0.0091 Acc: 96.04%
# Epoch [2/10] Loss: 0.0732 Acc: 96.07%
# Epoch [2/10] Loss: 0.0281 Acc: 96.10%
# Epoch [2/10] Loss: 0.1051 Acc: 96.13%
# Epoch [2/10] Loss: 0.0170 Acc: 96.15%
# Epoch [2/10] Loss: 0.2431 Acc: 96.18%
# Epoch [2/10] Loss: 0.0430 Acc: 96.21%
# Epoch [2/10] Loss: 0.0602 Acc: 96.23%
# Epoch [2/10] Loss: 0.0265 Acc: 96.26%
# Epoch [2/10] Loss: 0.0576 Acc: 96.28%
# Epoch [2/10] Loss: 0.0257 Acc: 96.31%
# Epoch [2/10] Loss: 0.0433 Acc: 96.33%
# Epoch [2/10] Loss: 0.0084 Acc: 96.36%
# Epoch [2/10] Loss: 0.0488 Acc: 96.38%
# Epoch [2/10] Loss: 0.6030 Acc: 96.41%
# Epoch [2/10] Loss: 0.1470 Acc: 96.43%
# Epoch [2/10] Loss: 0.0039 Acc: 96.45%
# Epoch [2/10] Loss: 0.0343 Acc: 96.47%
# Epoch [2/10] Loss: 0.0162 Acc: 96.50%
# Epoch [2/10] Loss: 1.4745 Acc: 96.20%
# Epoch [2/10] Loss: 0.0096 Acc: 96.23%
# Epoch [2/10] Loss: 0.0033 Acc: 96.25%
# Epoch [2/10] Loss: 0.1468 Acc: 96.27%
# Epoch [2/10] Loss: 0.0051 Acc: 96.30%
# Epoch [2/10] Loss: 0.0068 Acc: 96.32%
# Epoch [2/10] Loss: 0.0679 Acc: 96.34%
# Epoch [2/10] Loss: 0.0587 Acc: 96.36%
# Epoch [2/10] Loss: 0.1013 Acc: 96.39%
# Epoch [2/10] Loss: 0.0924 Acc: 96.41%
# Epoch [2/10] Loss: 0.0251 Acc: 96.43%
# Epoch [2/10] Loss: 0.0301 Acc: 96.45%
# Epoch [2/10] Loss: 0.7740 Acc: 96.18%
# Epoch [2/10] Loss: 0.0114 Acc: 96.20%
# Epoch [2/10] Loss: 0.0220 Acc: 96.22%
# Epoch [2/10] Loss: 0.0324 Acc: 96.24%
# Epoch [2/10] Loss: 0.0827 Acc: 96.26%
# Epoch [2/10] Loss: 0.0035 Acc: 96.29%
# Epoch [2/10] Loss: 0.0531 Acc: 96.31%
# Epoch [2/10] Loss: 0.2156 Acc: 96.33%
# Epoch [2/10] Loss: 0.0145 Acc: 96.35%
# Epoch [2/10] Loss: 0.1726 Acc: 96.37%
# Epoch [2/10] Loss: 0.0105 Acc: 96.39%
# Epoch [2/10] Loss: 0.0424 Acc: 96.41%
# Epoch [2/10] Loss: 0.2248 Acc: 96.43%
# Epoch [2/10] Loss: 0.0270 Acc: 96.45%
# Epoch [2/10] Loss: 0.1233 Acc: 96.47%
# Epoch [2/10] Loss: 0.0754 Acc: 96.49%
# Epoch [2/10] Loss: 0.1818 Acc: 96.51%
# Epoch [2/10] Loss: 0.0141 Acc: 96.52%
# Epoch [2/10] Loss: 0.0276 Acc: 96.54%
# Epoch [2/10] Loss: 0.1729 Acc: 96.56%
# Epoch [2/10] Loss: 0.0083 Acc: 96.58%
# Epoch [2/10] Loss: 0.0193 Acc: 96.60%
# Epoch [2/10] Loss: 0.8609 Acc: 96.35%
# Epoch [2/10] Loss: 0.0157 Acc: 96.37%
# Epoch [2/10] Loss: 0.0087 Acc: 96.39%
# Epoch [2/10] Loss: 0.0167 Acc: 96.41%
# Epoch [2/10] Loss: 0.0143 Acc: 96.43%
# Epoch [2/10] Loss: 0.0818 Acc: 96.45%
# Epoch [2/10] Loss: 0.1663 Acc: 96.46%
# Epoch [2/10] Loss: 0.0599 Acc: 96.48%
# Epoch [2/10] Loss: 0.0213 Acc: 96.50%
# Epoch [2/10] Loss: 0.1100 Acc: 96.52%
# Epoch [2/10] Loss: 0.0872 Acc: 96.53%
# Epoch [2/10] Loss: 0.6338 Acc: 96.31%
# Epoch [2/10] Loss: 0.4536 Acc: 96.08%
# Epoch [2/10] Loss: 0.0109 Acc: 96.10%
# Epoch [2/10] Loss: 0.9906 Acc: 95.87%
# Epoch [2/10] Loss: 0.7804 Acc: 95.65%
# Epoch [2/10] Loss: 0.0518 Acc: 95.67%
# Epoch [2/10] Loss: 0.0249 Acc: 95.69%
# Epoch [2/10] Loss: 0.1281 Acc: 95.71%
# Epoch [2/10] Loss: 0.0223 Acc: 95.73%
# Epoch [2/10] Loss: 0.2650 Acc: 95.75%
# Epoch [2/10] Loss: 0.0476 Acc: 95.77%
# Epoch [2/10] Loss: 0.0376 Acc: 95.79%
# Epoch [2/10] Loss: 0.5725 Acc: 95.58%
# Epoch [2/10] Loss: 0.1070 Acc: 95.60%
# Epoch [2/10] Loss: 0.0122 Acc: 95.62%
# Epoch [2/10] Loss: 0.1474 Acc: 95.64%
# Epoch [2/10] Loss: 0.1438 Train Acc: 95.64% | Val Acc: 85.90%
# New Best Model Saved with Accuracy: 85.90%
# Epoch [3/10]:   0%|          | 0/218 [00:00<?, ?it/s]
# Epoch [3/10] Loss: 0.0249 Acc: 100.00%
# Epoch [3/10] Loss: 0.0867 Acc: 100.00%
# Epoch [3/10] Loss: 0.0491 Acc: 100.00%
# Epoch [3/10] Loss: 0.0224 Acc: 100.00%
# Epoch [3/10] Loss: 0.1863 Acc: 100.00%
# Epoch [3/10] Loss: 0.0076 Acc: 100.00%
# Epoch [3/10] Loss: 0.0975 Acc: 100.00%
# Epoch [3/10] Loss: 0.0317 Acc: 100.00%
# Epoch [3/10] Loss: 0.0166 Acc: 100.00%
# Epoch [3/10] Loss: 0.0401 Acc: 100.00%
# Epoch [3/10] Loss: 0.0229 Acc: 100.00%
# Epoch [3/10] Loss: 0.0117 Acc: 100.00%
# Epoch [3/10] Loss: 0.0161 Acc: 100.00%
# Epoch [3/10] Loss: 0.0079 Acc: 100.00%
# Epoch [3/10] Loss: 0.0114 Acc: 100.00%
# Epoch [3/10] Loss: 0.0126 Acc: 100.00%
# Epoch [3/10] Loss: 0.0172 Acc: 100.00%
# Epoch [3/10] Loss: 0.0133 Acc: 100.00%
# Epoch [3/10] Loss: 0.0137 Acc: 100.00%
# Epoch [3/10] Loss: 0.0127 Acc: 100.00%
# Epoch [3/10] Loss: 0.0103 Acc: 100.00%
# Epoch [3/10] Loss: 0.0132 Acc: 100.00%
# Epoch [3/10] Loss: 0.0122 Acc: 100.00%
# Epoch [3/10] Loss: 0.0124 Acc: 100.00%
# Epoch [3/10] Loss: 0.0822 Acc: 100.00%
# Epoch [3/10] Loss: 0.0493 Acc: 100.00%
# Epoch [3/10] Loss: 0.0095 Acc: 100.00%
# Epoch [3/10] Loss: 0.0345 Acc: 100.00%
# Epoch [3/10] Loss: 0.0108 Acc: 100.00%
# Epoch [3/10] Loss: 0.1090 Acc: 100.00%
# Epoch [3/10] Loss: 0.0108 Acc: 100.00%
# Epoch [3/10] Loss: 0.0202 Acc: 100.00%
# Epoch [3/10] Loss: 0.0897 Acc: 100.00%
# Epoch [3/10] Loss: 0.1377 Acc: 100.00%
# Epoch [3/10] Loss: 0.0577 Acc: 100.00%
# Epoch [3/10] Loss: 0.0493 Acc: 100.00%
# Epoch [3/10] Loss: 0.0570 Acc: 100.00%
# Epoch [3/10] Loss: 0.0172 Acc: 100.00%
# Epoch [3/10] Loss: 0.0070 Acc: 100.00%
# Epoch [3/10] Loss: 0.0044 Acc: 100.00%
# Epoch [3/10] Loss: 0.0281 Acc: 100.00%
# Epoch [3/10] Loss: 0.0073 Acc: 100.00%
# Epoch [3/10] Loss: 0.0152 Acc: 100.00%
# Epoch [3/10] Loss: 0.0228 Acc: 100.00%
# Epoch [3/10] Loss: 0.0290 Acc: 100.00%
# Epoch [3/10] Loss: 0.0089 Acc: 100.00%
# Epoch [3/10] Loss: 0.0055 Acc: 100.00%
# Epoch [3/10] Loss: 0.0810 Acc: 100.00%
# Epoch [3/10] Loss: 0.0030 Acc: 100.00%
# Epoch [3/10] Loss: 0.0298 Acc: 100.00%
# Epoch [3/10] Loss: 0.0075 Acc: 100.00%
# Epoch [3/10] Loss: 0.0104 Acc: 100.00%
# Epoch [3/10] Loss: 0.0120 Acc: 100.00%
# Epoch [3/10] Loss: 0.0115 Acc: 100.00%
# Epoch [3/10] Loss: 0.0102 Acc: 100.00%
# Epoch [3/10] Loss: 0.0035 Acc: 100.00%
# Epoch [3/10] Loss: 0.0974 Acc: 100.00%
# Epoch [3/10] Loss: 0.0975 Acc: 100.00%
# Epoch [3/10] Loss: 0.0041 Acc: 100.00%
# Epoch [3/10] Loss: 0.0177 Acc: 100.00%
# Epoch [3/10] Loss: 0.0070 Acc: 100.00%
# Epoch [3/10] Loss: 0.0059 Acc: 100.00%
# Epoch [3/10] Loss: 0.0028 Acc: 100.00%
# Epoch [3/10] Loss: 0.0224 Acc: 100.00%
# Epoch [3/10] Loss: 0.0102 Acc: 100.00%
# Epoch [3/10] Loss: 0.0148 Acc: 100.00%
# Epoch [3/10] Loss: 0.0225 Acc: 100.00%
# Epoch [3/10] Loss: 0.0031 Acc: 100.00%
# Epoch [3/10] Loss: 0.0353 Acc: 100.00%
# Epoch [3/10] Loss: 0.0213 Acc: 100.00%
# Epoch [3/10] Loss: 0.0075 Acc: 100.00%
# Epoch [3/10] Loss: 0.0477 Acc: 100.00%
# Epoch [3/10] Loss: 0.0054 Acc: 100.00%
# Epoch [3/10] Loss: 0.0217 Acc: 100.00%
# Epoch [3/10] Loss: 0.0042 Acc: 100.00%
# Epoch [3/10] Loss: 0.0048 Acc: 100.00%
# Epoch [3/10] Loss: 0.0027 Acc: 100.00%
# Epoch [3/10] Loss: 0.0185 Acc: 100.00%
# Epoch [3/10] Loss: 0.0131 Acc: 100.00%
# Epoch [3/10] Loss: 0.0189 Acc: 100.00%
# Epoch [3/10] Loss: 0.0140 Acc: 100.00%
# Epoch [3/10] Loss: 0.0046 Acc: 100.00%
# Epoch [3/10] Loss: 0.0145 Acc: 100.00%
# Epoch [3/10] Loss: 0.0143 Acc: 100.00%
# Epoch [3/10] Loss: 0.0077 Acc: 100.00%
# Epoch [3/10] Loss: 0.0232 Acc: 100.00%
# Epoch [3/10] Loss: 0.0069 Acc: 100.00%
# Epoch [3/10] Loss: 0.0256 Acc: 100.00%
# Epoch [3/10] Loss: 0.0029 Acc: 100.00%
# Epoch [3/10] Loss: 0.0140 Acc: 100.00%
# Epoch [3/10] Loss: 0.0593 Acc: 100.00%
# Epoch [3/10] Loss: 0.0269 Acc: 100.00%
# Epoch [3/10] Loss: 0.0122 Acc: 100.00%
# Epoch [3/10] Loss: 0.0046 Acc: 100.00%
# Epoch [3/10] Loss: 0.1679 Acc: 100.00%
# Epoch [3/10] Loss: 0.0065 Acc: 100.00%
# Epoch [3/10] Loss: 0.0033 Acc: 100.00%
# Epoch [3/10] Loss: 0.0055 Acc: 100.00%
# Epoch [3/10] Loss: 0.0133 Acc: 100.00%
# Epoch [3/10] Loss: 0.0070 Acc: 100.00%
# Epoch [3/10] Loss: 0.0632 Acc: 100.00%
# Epoch [3/10] Loss: 0.0134 Acc: 100.00%
# Epoch [3/10] Loss: 0.0200 Acc: 100.00%
# Epoch [3/10] Loss: 0.0133 Acc: 100.00%
# Epoch [3/10] Loss: 0.0089 Acc: 100.00%
# Epoch [3/10] Loss: 0.0077 Acc: 100.00%
# Epoch [3/10] Loss: 0.0087 Acc: 100.00%
# Epoch [3/10] Loss: 0.0085 Acc: 100.00%
# Epoch [3/10] Loss: 0.0040 Acc: 100.00%
# Epoch [3/10] Loss: 0.0119 Acc: 100.00%
# Epoch [3/10] Loss: 0.0017 Acc: 100.00%
# Epoch [3/10] Loss: 0.0040 Acc: 100.00%
# Epoch [3/10] Loss: 0.0105 Acc: 100.00%
# Epoch [3/10] Loss: 0.0025 Acc: 100.00%
# Epoch [3/10] Loss: 0.0139 Acc: 100.00%
# Epoch [3/10] Loss: 0.0032 Acc: 100.00%
# Epoch [3/10] Loss: 0.0051 Acc: 100.00%
# Epoch [3/10] Loss: 0.0032 Acc: 100.00%
# Epoch [3/10] Loss: 0.0030 Acc: 100.00%
# Epoch [3/10] Loss: 0.0610 Acc: 100.00%
# Epoch [3/10] Loss: 0.0144 Acc: 100.00%
# Epoch [3/10] Loss: 0.0082 Acc: 100.00%
# Epoch [3/10] Loss: 0.0121 Acc: 100.00%
# Epoch [3/10] Loss: 0.0089 Acc: 100.00%
# Epoch [3/10] Loss: 0.0210 Acc: 100.00%
# Epoch [3/10] Loss: 0.0232 Acc: 100.00%
# Epoch [3/10] Loss: 0.0041 Acc: 100.00%
# Epoch [3/10] Loss: 0.0027 Acc: 100.00%
# Epoch [3/10] Loss: 0.0044 Acc: 100.00%
# Epoch [3/10] Loss: 0.0096 Acc: 100.00%
# Epoch [3/10] Loss: 0.0198 Acc: 100.00%
# Epoch [3/10] Loss: 0.0058 Acc: 100.00%
# Epoch [3/10] Loss: 0.0068 Acc: 100.00%
# Epoch [3/10] Loss: 0.0062 Acc: 100.00%
# Epoch [3/10] Loss: 0.0027 Acc: 100.00%
# Epoch [3/10] Loss: 0.0077 Acc: 100.00%
# Epoch [3/10] Loss: 0.0054 Acc: 100.00%
# Epoch [3/10] Loss: 0.0842 Acc: 100.00%
# Epoch [3/10] Loss: 0.0183 Acc: 100.00%
# Epoch [3/10] Loss: 0.0028 Acc: 100.00%
# Epoch [3/10] Loss: 0.0050 Acc: 100.00%
# Epoch [3/10] Loss: 0.0213 Acc: 100.00%
# Epoch [3/10] Loss: 0.0050 Acc: 100.00%
# Epoch [3/10] Loss: 0.0070 Acc: 100.00%
# Epoch [3/10] Loss: 0.0050 Acc: 100.00%
# Epoch [3/10] Loss: 0.0066 Acc: 100.00%
# Epoch [3/10] Loss: 0.0037 Acc: 100.00%
# Epoch [3/10] Loss: 0.0026 Acc: 100.00%
# Epoch [3/10] Loss: 0.0029 Acc: 100.00%
# Epoch [3/10] Loss: 0.0051 Acc: 100.00%
# Epoch [3/10] Loss: 0.0088 Acc: 100.00%
# Epoch [3/10] Loss: 0.0059 Acc: 100.00%
# Epoch [3/10] Loss: 0.0066 Acc: 100.00%
# Epoch [3/10] Loss: 0.0156 Acc: 100.00%
# Epoch [3/10] Loss: 0.0091 Acc: 100.00%
# Epoch [3/10] Loss: 0.0074 Acc: 100.00%
# Epoch [3/10] Loss: 0.0079 Acc: 100.00%
# Epoch [3/10] Loss: 0.0119 Acc: 100.00%
# Epoch [3/10] Loss: 0.0118 Acc: 100.00%
# Epoch [3/10] Loss: 0.0253 Acc: 100.00%
# Epoch [3/10] Loss: 0.0032 Acc: 100.00%
# Epoch [3/10] Loss: 0.0213 Acc: 100.00%
# Epoch [3/10] Loss: 0.0036 Acc: 100.00%
# Epoch [3/10] Loss: 0.0027 Acc: 100.00%
# Epoch [3/10] Loss: 0.0060 Acc: 100.00%
# Epoch [3/10] Loss: 0.0052 Acc: 100.00%
# Epoch [3/10] Loss: 0.0090 Acc: 100.00%
# Epoch [3/10] Loss: 0.0023 Acc: 100.00%
# Epoch [3/10] Loss: 0.0110 Acc: 100.00%
# Epoch [3/10] Loss: 0.0032 Acc: 100.00%
# Epoch [3/10] Loss: 0.0039 Acc: 100.00%
# Epoch [3/10] Loss: 0.0033 Acc: 100.00%
# Epoch [3/10] Loss: 0.0161 Acc: 100.00%
# Epoch [3/10] Loss: 0.0038 Acc: 100.00%
# Epoch [3/10] Loss: 0.0089 Acc: 100.00%
# Epoch [3/10] Loss: 0.0021 Acc: 100.00%
# Epoch [3/10] Loss: 0.0052 Acc: 100.00%
# Epoch [3/10] Loss: 0.0131 Acc: 100.00%
# Epoch [3/10] Loss: 0.0029 Acc: 100.00%
# Epoch [3/10] Loss: 0.0020 Acc: 100.00%
# Epoch [3/10] Loss: 0.0081 Acc: 100.00%
# Epoch [3/10] Loss: 0.0049 Acc: 100.00%
# Epoch [3/10] Loss: 0.0041 Acc: 100.00%
# Epoch [3/10] Loss: 0.0078 Acc: 100.00%
# Epoch [3/10] Loss: 0.0023 Acc: 100.00%
# Epoch [3/10] Loss: 0.0062 Acc: 100.00%
# Epoch [3/10] Loss: 0.0066 Acc: 100.00%
# Epoch [3/10] Loss: 0.0018 Acc: 100.00%
# Epoch [3/10] Loss: 0.0033 Acc: 100.00%
# Epoch [3/10] Loss: 0.0037 Acc: 100.00%
# Epoch [3/10] Loss: 0.0055 Acc: 100.00%
# Epoch [3/10] Loss: 0.0035 Acc: 100.00%
# Epoch [3/10] Loss: 0.3560 Acc: 100.00%
# Epoch [3/10] Loss: 0.0038 Acc: 100.00%
# Epoch [3/10] Loss: 0.0131 Acc: 100.00%
# Epoch [3/10] Loss: 0.0032 Acc: 100.00%
# Epoch [3/10] Loss: 0.0563 Acc: 100.00%
# Epoch [3/10] Loss: 0.0148 Acc: 100.00%
# Epoch [3/10] Loss: 0.0105 Acc: 100.00%
# Epoch [3/10] Loss: 0.0859 Acc: 100.00%
# Epoch [3/10] Loss: 0.0143 Acc: 100.00%
# Epoch [3/10] Loss: 0.0057 Acc: 100.00%
# Epoch [3/10] Loss: 0.0078 Acc: 100.00%
# Epoch [3/10] Loss: 0.0250 Acc: 100.00%
# Epoch [3/10] Loss: 0.0159 Acc: 100.00%
# Epoch [3/10] Loss: 0.0063 Acc: 100.00%
# Epoch [3/10] Loss: 0.0152 Acc: 100.00%
# Epoch [3/10] Loss: 0.0054 Acc: 100.00%
# Epoch [3/10] Loss: 0.0066 Acc: 100.00%
# Epoch [3/10] Loss: 0.0346 Acc: 100.00%
# Epoch [3/10] Loss: 0.0025 Acc: 100.00%
# Epoch [3/10] Loss: 0.0047 Acc: 100.00%
# Epoch [3/10] Loss: 0.0020 Acc: 100.00%
# Epoch [3/10] Loss: 0.0065 Acc: 100.00%
# Epoch [3/10] Loss: 0.0676 Acc: 100.00%
# Epoch [3/10] Loss: 0.2051 Acc: 100.00%
# Epoch [3/10] Loss: 0.0128 Acc: 100.00%
# Epoch [3/10] Loss: 0.0082 Acc: 100.00%
# Epoch [3/10] Loss: 0.0211 Train Acc: 100.00% | Val Acc: 91.03%
# New Best Model Saved with Accuracy: 91.03%
# Epoch [4/10]:   0%|          | 0/218 [00:00<?, ?it/s]
# Epoch [4/10] Loss: 0.0056 Acc: 100.00%
# Epoch [4/10] Loss: 0.0040 Acc: 100.00%
# Epoch [4/10] Loss: 0.0122 Acc: 100.00%
# Epoch [4/10] Loss: 0.0051 Acc: 100.00%
# Epoch [4/10] Loss: 0.0068 Acc: 100.00%
# Epoch [4/10] Loss: 0.0079 Acc: 100.00%
# Epoch [4/10] Loss: 0.0304 Acc: 100.00%
# Epoch [4/10] Loss: 0.0132 Acc: 100.00%
# Epoch [4/10] Loss: 0.0100 Acc: 100.00%
# Epoch [4/10] Loss: 0.0020 Acc: 100.00%
# Epoch [4/10] Loss: 0.0088 Acc: 100.00%
# Epoch [4/10] Loss: 0.0095 Acc: 100.00%
# Epoch [4/10] Loss: 0.0037 Acc: 100.00%
# Epoch [4/10] Loss: 0.0014 Acc: 100.00%
# Epoch [4/10] Loss: 0.0058 Acc: 100.00%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-84437bf9704e> in <cell line: 0>()
#       8
#       9 # Train and validate the model.
# ---> 10 train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)
#      11
#      12 # Load the best saved model for final testing.
#
# <ipython-input-21-326e418b8fab> in train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      44             optimizer.step()
#      45
# ---> 46             running_loss += loss.item() * labels.size(0)
#      47             _, predicted = outputs.max(1)
#      48             correct += (predicted == labels).sum().item()
#
# KeyboardInterrupt:

# %%
import os
import shutil
import random
from pathlib import Path

def split_dataset(source_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    # Ensure ratios sum to 1
    assert train_ratio + val_ratio + test_ratio == 1, "Ratios must sum to 1"

    # Create train, val, test directories
    base_path = Path(source_dir).parent
    for split in ['train', 'val', 'test']:
        split_path = base_path / f'{source_dir}-{split}'
        if split_path.exists():
            shutil.rmtree(split_path)
        split_path.mkdir(exist_ok=True)

    # Get all class directories
    class_dirs = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d)) and not d.startswith('.')]

    for class_name in class_dirs:
        # Create class subdirectories in each split
        for split in ['train', 'val', 'test']:
            os.makedirs(os.path.join(f'{source_dir}-{split}', class_name), exist_ok=True)

        # Get all videos for this class
        videos = [v for v in os.listdir(os.path.join(source_dir, class_name))
                 if v.endswith(('.mp4', '.avi', '.mov'))]
        random.shuffle(videos)
        print(f"Class '{class_name}' has {len(videos)} videos.")
        # Ensure at least 1 sample per class in val and test sets
        n_videos = len(videos)
        if n_videos < 3:
            raise ValueError(f"Class '{class_name}' has less than 3 videos. At least 3 are needed for splitting!")

        # Assign at least one sample to val and test sets
        n_val = max(1, int(val_ratio * n_videos))
        n_test = max(1, int(test_ratio * n_videos))
        n_train = n_videos - n_val - n_test  # Remaining goes to train

        # Split videos
        train_videos = videos[:n_train]
        val_videos = videos[n_train:n_train + n_val]
        test_videos = videos[n_train + n_val:]

        # Copy videos to respective directories
        for video, split_dir in [
            (train_videos, f'{source_dir}-train'),
            (val_videos, f'{source_dir}-val'),
            (test_videos, f'{source_dir}-test')
        ]:
            for v in video:
                src = os.path.join(source_dir, class_name, v)
                dst = os.path.join(split_dir, class_name, v)
                shutil.copy2(src, dst)

        print(f"Class '{class_name}' split complete:")
        print(f"Train: {len(train_videos)}, Val: {len(val_videos)}, Test: {len(test_videos)}")

if __name__ == "__main__":
    split_dataset('/content/drive/MyDrive/CS_6998/workoutfitness-video')
    print("Dataset splitting complete!")
# Out:
# Class 'incline bench press' has 33 videos.
# Class 'incline bench press' split complete:
# Train: 25, Val: 4, Test: 4
# Class 'leg raises' has 15 videos.
# Class 'leg raises' split complete:
# Train: 11, Val: 2, Test: 2
# Class 'pull Up' has 26 videos.
# Class 'pull Up' split complete:
# Train: 20, Val: 3, Test: 3
# Class 'romanian deadlift' has 12 videos.
# Class 'romanian deadlift' split complete:
# Train: 10, Val: 1, Test: 1
# Class 'hip thrust' has 14 videos.
# Class 'hip thrust' split complete:
# Train: 10, Val: 2, Test: 2
# Class 'plank' has 6 videos.
# Class 'plank' split complete:
# Train: 4, Val: 1, Test: 1
# Class 'tricep dips' has 16 videos.
# Class 'tricep dips' split complete:
# Train: 12, Val: 2, Test: 2
# Class 'chest fly machine' has 28 videos.
# Class 'chest fly machine' split complete:
# Train: 20, Val: 4, Test: 4
# Class 'russian twist' has 12 videos.
# Class 'russian twist' split complete:
# Train: 10, Val: 1, Test: 1
# Class 'hammer curl' has 12 videos.
# Class 'hammer curl' split complete:
# Train: 10, Val: 1, Test: 1
# Class 'lateral raise' has 31 videos.
# Class 'lateral raise' split complete:
# Train: 23, Val: 4, Test: 4
# Class 'lat pulldown' has 51 videos.
# Class 'lat pulldown' split complete:
# Train: 37, Val: 7, Test: 7
# Class 'barbell biceps curl' has 62 videos.
# Class 'barbell biceps curl' split complete:
# Train: 44, Val: 9, Test: 9
# Class 'deadlift' has 32 videos.
# Class 'deadlift' split complete:
# Train: 24, Val: 4, Test: 4
# Class 't bar row' has 14 videos.
# Class 't bar row' split complete:
# Train: 10, Val: 2, Test: 2
# Class 'squat' has 23 videos.
# Class 'squat' split complete:
# Train: 17, Val: 3, Test: 3
# Class 'leg extension' has 19 videos.
# Class 'leg extension' split complete:
# Train: 15, Val: 2, Test: 2
# Class 'decline bench press' has 6 videos.
# Class 'decline bench press' split complete:
# Train: 4, Val: 1, Test: 1
# Class 'push-up' has 56 videos.
# Class 'push-up' split complete:
# Train: 40, Val: 8, Test: 8
# Class 'bench press' has 61 videos.
# Class 'bench press' split complete:
# Train: 43, Val: 9, Test: 9
# Class 'shoulder press' has 13 videos.
# Class 'shoulder press' split complete:
# Train: 11, Val: 1, Test: 1
# Class 'tricep Pushdown' has 50 videos.
# Class 'tricep Pushdown' split complete:
# Train: 36, Val: 7, Test: 7
# Dataset splitting complete!

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hasyimabdillah/workoutfitness-video")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/hasyimabdillah/workoutfitness-video?dataset_version_number=5...
# 100%|██████████| 4.32G/4.32G [00:59<00:00, 77.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/hasyimabdillah/workoutfitness-video/versions/5

# %%
import shutil
source_path = "/root/.cache/kagglehub/datasets/hasyimabdillah/workoutfitness-video/versions/5"
destination_path = "/content/drive/MyDrive/datasets/workoutfitness-video"
shutil.copytree(source_path, destination_path)
print("Copied dataset to:", destination_path)
# Out:
# Copied dataset to: /content/drive/MyDrive/datasets/workoutfitness-video
